# %%
import numpy as np
import pickle
import sys
sys.path.append("../")
from src.utils import get_cell_x, get_cell_y, get_best_frequency_by_peak, get_best_frequency_by_area, get_active_cells

# %%
# get the stimulus file
with open('/home/bic/vtarka/Documents/Vid_202/cells_d.pkl', 'rb') as f:
    cell_dictionary = pickle.load(f)

# %%
cell_dict = get_active_cells(cell_dictionary)
print(len(cell_dict))
# Out:
# 86

# %%
print(cell_dict.keys())
print(cell_dict[12].keys())
# Out:
# dict_keys([2, 3, 4, 5, 6, 7, 9, 10, 11, 12, 13, 14, 16, 18, 20, 21, 22, 25, 26, 27, 28, 29, 30, 33, 34, 35, 36, 39, 42, 43, 44, 45, 46, 48, 50, 51, 52, 53, 54, 56, 57, 58, 59, 60, 62, 63, 65, 67, 68, 69, 70, 71, 72, 74, 76, 77, 78, 79, 86, 87, 89, 90, 91, 92, 93, 95, 97, 100, 101, 102, 103, 104, 105, 106, 108, 110, 111, 113, 115, 118, 119, 121, 125, 129, 131, 135])
# dict_keys(['traces', 'active', 'tuning_curve_peak', 'x', 'y'])

# %%
import matplotlib.pyplot as plt
from matplotlib import cm

# %%
x = []
y = []
c = []
for cell in cell_dict:
    x.append((cell_dict[cell]['x']))
    y.append((cell_dict[cell]['y']))
    c.append(get_best_frequency_by_peak(cell_dict[cell]))

plt.scatter(x,y,c=c,cmap=plt.get_cmap("inferno"))
plt.colorbar()
plt.title("BF by peak")
plt.show()

# %%
print(np.arange(0,48,4))
# Out:
# [ 0  4  8 12 16 20 24 28 32 36 40 44]

# %%
plt.hist(c,bins=np.arange(0,50,4))
plt.yticks(np.arange(0,22,2))
plt.show()

# %%
c_pre = c
