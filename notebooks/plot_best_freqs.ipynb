# %%
import numpy as np
import pickle
import sys
sys.path.append("../")
from src.utils import get_cell_x, get_cell_y, get_best_frequency_by_area, get_active_cells

# %%
def get_best_frequency(cell_tuning,freqs):
    median_across_itsies = np.median(cell_tuning, axis=1)
    max_response_idx = np.argmax(median_across_itsies)
    return freqs[max_response_idx]

# %%
with open('/media/vtarka/USB DISK/Lab/2P/Vid_217/cells_ns.pkl', 'rb') as f:
        cell_dictionary = pickle.load(f)

# %%
cell_dict = get_active_cells(cell_dictionary)
print(len(cell_dict))
# Out:
# 163

# %%
print(cell_dict.keys())
print(cell_dict[12]['tuning_curve_peak'])
# Out:
# dict_keys([1, 2, 3, 5, 6, 8, 11, 13, 15, 16, 17, 19, 21, 28, 29, 30, 31, 33, 34, 36, 37, 38, 39, 41, 42, 44, 49, 53, 54, 56, 58, 63, 64, 66, 68, 70, 75, 76, 78, 80, 81, 82, 83, 84, 88, 89, 91, 92, 95, 101, 103, 105, 106, 107, 109, 114, 115, 118, 128, 130, 132, 136, 137, 142, 143, 145, 147, 148, 149, 157, 161, 162, 163, 169, 170, 176, 178, 180, 182, 183, 184, 186, 194, 202, 205, 216, 219, 220, 221, 226, 228, 236, 237, 251, 253, 257, 259, 260, 276, 290, 291, 294, 299, 303, 311, 312, 316, 319, 322, 324, 325, 326, 329, 343, 349, 356, 357, 358, 359, 370, 371, 372, 375, 384, 395, 410, 420, 437, 442, 455, 468, 471, 479, 489, 518, 529, 535, 538, 549, 560, 567, 568, 571, 579, 596, 644, 700, 704, 744, 757, 761, 780, 815, 817, 864, 888, 964, 1007, 1029, 1046, 1208, 1245, 1722])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-fc6babb81dc2> in <module>
#       1 print(cell_dict.keys())
# ----> 2 print(cell_dict[12]['tuning_curve_peak'])
#
# KeyError: 12

# %%
import matplotlib.pyplot as plt
from matplotlib import cm

# %%
x = []
y = []
c = []
for cell in cell_dict:
    x.append((cell_dict[cell]['x']))
    y.append((cell_dict[cell]['y']))
    c.append(get_best_frequency(cell_dict[cell]['tuning_curve_peak'],[4.4,5.4,6.6,8.1,10,12,15,19,23,28,28,35,43]))

plt.scatter(x,y,c=c,cmap=plt.get_cmap("inferno"))
plt.colorbar()
plt.title("BF by peak")
plt.show()

# %%
plt.hist(c)
# Out:
# (array([36., 34., 13., 12.,  9.,  0.,  9., 42.,  0.,  8.]),
#  array([ 4.4 ,  7.46, 10.52, 13.58, 16.64, 19.7 , 22.76, 25.82, 28.88,
#         31.94, 35.  ]),
#  <BarContainer object of 10 artists>)

# %%
c_pre = c
