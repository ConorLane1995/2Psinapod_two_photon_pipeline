# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy
import seaborn as sns
import pandas as pd
from scipy.stats import sem

# %%
saline_pre = pd.DataFrame([510,438,373,338,437,531,694])
saline_post = pd.DataFrame([449,380,371,341,335,472,648])
psilocybin_pre = pd.DataFrame([278,475,412,512,299,540,708])
psilocybin_post = pd.DataFrame([373,480,434,664,299,484,714])

df_2 = pd.DataFrame(columns=['saline pre','saline post','psilo pre','psilo post'])
df_2['saline pre'] = saline_pre
df_2['saline post'] = saline_post
df_2['psilo pre'] = psilocybin_pre
df_2['psilo post'] = psilocybin_post

print(df_2)
# Out:
#    saline pre  saline post  psilo pre  psilo post
# 0         510          449        278         373
# 1         438          380        475         480
# 2         373          371        412         434
# 3         338          341        512         664
# 4         437          335        299         299
# 5         531          472        540         484
# 6         694          648        708         714

# %%
saline_pre_active = pd.DataFrame([194,185,162,233,132,359])
saline_post_active = pd.DataFrame([167,146,130,162,116,341])
psilocybin_pre_active = pd.DataFrame([83,188,220,141,150,343])
psilocybin_post_active = pd.DataFrame([98,170,272,142,132,340])

df_3 = pd.DataFrame(columns=['saline active pre','saline active post','psilo active pre','psilo active post'])
df_3['saline active pre'] = saline_pre_active
df_3['saline active post'] = saline_post_active
df_3['psilo active pre'] = psilocybin_pre_active
df_3['psilo active post'] = psilocybin_post_active

# %%
ax = sns.boxplot(data=df_3),
sns.stripplot(data=df_3,color='black')
plt.ylabel("Responsive Cell Count")

plt.show()
# Out:
# C:\Users\Conor\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:166: FutureWarning: Setting a gradient palette using color= is deprecated and will be removed in version 0.13. Set `palette='dark:black'` for same effect.
#   warnings.warn(msg, FutureWarning)

# %%
scipy.stats.ttest_rel(saline_pre_active,saline_post_active)
# Out:
# Ttest_relResult(statistic=array([4.11619931]), pvalue=array([0.00920798]))

# %%
df_percent = pd.DataFrame(columns=['Saline','Psilocybin'])

saline_percent = pd.DataFrame([-11.96078431,-13.24200913,-0.5361930295,0.8875739645,-23.3409611,-11.11111111,-6.628242075])
psilocybin_percent = pd.DataFrame([15.96091205,9.195402299,13.24786325,30.12048193,3.76344086,21.7721519,23.01587302,26.4957265])

df_percent['Saline'] = saline_percent
df_percent['Psilocybin'] = psilocybin_percent

# %%
df_percent_active = pd.DataFrame(columns=['Saline','Psilocybin'])

saline_percent_active = pd.DataFrame([17.05069124,24.48979592,16.38418079,26.76767677,8.108108108,33.96226415,27.43362832,31.37254902])
psilocybin_percent_active = pd.DataFrame([15.96091205,9.195402299,13.24786325,30.12048193,3.76344086,21.7721519,23.01587302,26.4957265])

df_percent_active['Saline'] = saline_percent_active
df_percent_active['Psilocybin'] = psilocybin_percent_active

# %%
scipy.stats.ttest_ind(saline_percent_active,psilocybin_percent_active)
# P value = 0.015
# Out:
# Ttest_indResult(statistic=array([1.18861303]), pvalue=array([0.25436381]))

# %%
# Plotting the boxplot
ax = sns.boxplot(data=df_percent_active)
sns.stripplot(data=df_percent_active, color='black')

# Adding labels and title to the boxplot
plt.ylabel("% of Total Responsive Cells")
plt.title("Cells Responsive Only in First Recording, \n as a Percentage of Total Responsive Cells", pad=10)
plt.ylim(0,40)


# Drawing a line with "n.s" text
plt.axhline(xmin=0.25,xmax=0.75, y=36, color='black', linestyle='-')
plt.text(0.5, 37, 'n.s', horizontalalignment='center', verticalalignment='center')
# Out:
# C:\Users\Conor\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:166: FutureWarning: Setting a gradient palette using color= is deprecated and will be removed in version 0.13. Set `palette='dark:black'` for same effect.
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 37, 'n.s')

# %%
ax = sns.boxplot(data=df_percent_active),
sns.stripplot(data=df_percent_active,color='black')
plt.ylabel("% of Total Responsive Cells")
plt.title("Cells Responsive in Both Recordings, \n as a Percentage of Total Responsive Cells",pad=10)

plt.show()
# Out:
# C:\Users\Conor\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:166: FutureWarning: Setting a gradient palette using color= is deprecated and will be removed in version 0.13. Set `palette='dark:black'` for same effect.
#   warnings.warn(msg, FutureWarning)

# %%
# Out:
# [[inf inf]]
# C:\Users\Conor\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 12
#       8 SE[0,1] = np.std(psilocybin_percent_active) / np.sqrt(len(psilocybin_percent_active))
#      10 x = ['Saline', 'Psilocybin']
# ---> 12 plt.bar(x, means, yerr=SE)
#
# ...

# %%
ID276 = [-21.59928816,-11.44364698]
ID269 = [-34.84853862,-20.77963072]
ID251 = [-27.17791395,-2.27530088]
ID239 = [-23.14002138,-1.489039795]
ID237 = [-11.39532797,0.2656676324]
ID186 = [-17.29663857,-14.89734348]
ID184 = [-10.55917208,-12.3569226]
line1 = plt.plot(ID276,'k^-',label='276')
line2 = plt.plot(ID269,'mo-',label='269')
line3 = plt.plot(ID251,'ro-',label='251')
line4 = plt.plot(ID239,'y^-',label='239')
line5 = plt.plot(ID237,'go-',label='237')
line6 = plt.plot(ID186,'mo-',label='186')
line7 = plt.plot(ID184,'co-',label='184')


labels = ("Saline","Psilocybin")
plt.xticks(np.arange(2), labels)
plt.ylabel("% Change Active Cell Count")
plt.title("% Change in Active Cell Count for Saline and Psilocybin Conditions")

plt.show()

# %%
# scipy.stats.ttest_ind(saline_percent,psilocybin_percent)

scipy.stats.ttest_rel(saline_percent,psilocybin_percent)
#P 0.023
# Out:
# Ttest_relResult(statistic=array([-3.02179299]), pvalue=array([0.02334316]))

# %%
ax = sns.boxplot(data=df_percent),
sns.stripplot(data=df_percent,color='black')
plt.ylabel("% Change in Cell Count")

plt.show()
# Out:
# C:\Users\Conor\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:166: FutureWarning: Setting a gradient palette using color= is deprecated and will be removed in version 0.13. Set `palette='dark:black'` for same effect.
#   warnings.warn(msg, FutureWarning)

# %%
diff_saline = pd.DataFrame([-61,-58,-2,-3,-102,-59,-46])
diff_psilocybin = pd.DataFrame([95,5,22,152,0,-56,6])

df = pd.DataFrame(columns=['saline','psilo'])
df['saline'] = diff_saline
df['psilo'] = diff_psilocybin
print(df)
# Out:
#    saline  psilo
# 0     -61     95
# 1     -58      5
# 2      -2     22
# 3      -3    152
# 4    -102      0
# 5     -59    -56
# 6     -46      6

# %%
scipy.stats.ttest_ind(diff_saline,diff_psilocybin)
# Out:
# Ttest_indResult(statistic=array([-2.7047653]), pvalue=array([0.01913988]))

# %%
ax = sns.boxplot(data=df),
sns.stripplot(data=df,color='black')
plt.ylabel("Change in Cell Count")

plt.show()
# Out:
# C:\Users\Conor\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:166: FutureWarning: Setting a gradient palette using color= is deprecated and will be removed in version 0.13. Set `palette='dark:black'` for same effect.
#   warnings.warn(msg, FutureWarning)

# %%
ax = sns.boxplot(data=df_2),
sns.stripplot(data=df_2,color='black')
plt.ylabel("Cell Count")

plt.show()
# Out:
# C:\Users\Conor\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:166: FutureWarning: Setting a gradient palette using color= is deprecated and will be removed in version 0.13. Set `palette='dark:black'` for same effect.
#   warnings.warn(msg, FutureWarning)

# %%
df_mean_activity = pd.DataFrame(columns=['Saline','Psilocybin'])

saline_percent_mean_activity = pd.DataFrame([-10.55917208,-17.29663857,-23.14002138,-27.17791395,-34.84853862,-21.59928816,-11.39532797])
psilocybin_percent_mean_activity = pd.DataFrame([-12.3569226,-14.89734348,-1.489039795,-2.27530088,-20.77963072,-11.44364698,0.2656676324])

df_mean_activity['Saline'] = saline_percent_mean_activity
df_mean_activity['Psilocybin'] = psilocybin_percent_mean_activity

# %%
ax = sns.boxplot(data=df_mean_activity),
sns.stripplot(data=df_mean_activity,color='black')
plt.ylabel("% change in mean activity")
plt.title("Change in Mean Activity of Responsive Cells")

plt.show()
# Out:
# C:\Users\Conor\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:166: FutureWarning: Setting a gradient palette using color= is deprecated and will be removed in version 0.13. Set `palette='dark:black'` for same effect.
#   warnings.warn(msg, FutureWarning)

# %%
scipy.stats.ttest_rel(saline_percent_mean_activity,psilocybin_percent_mean_activity)
# P = 0.017
# Out:
# Ttest_relResult(statistic=array([-3.27869493]), pvalue=array([0.01685004]))

# %%
df_perc_change_sense = pd.DataFrame(columns=['Saline','Psilocybin'])

perc_change_sense_saline = pd.DataFrame([4.370216566,3.792608246,-2.081785459,6.759142497,1.034690022,2.032146145,-0.1574795201])
perc_change_sense_psilo = pd.DataFrame([-7.833133253,-0.4045116145,2.477777778,3.108504028,6.907771062,-3.743315508,-4.752033792])

df_perc_change_sense['Saline'] = perc_change_sense_saline
df_perc_change_sense['Psilocybin'] = perc_change_sense_psilo

ax = sns.boxplot(data=df_perc_change_sense),
sns.stripplot(data=df_perc_change_sense,color='black')
plt.ylabel("% change in mean sensitivity")
plt.title("Change in Mean Sensitivity of Responsive Cells")

plt.show()
# Out:
# C:\Users\Conor\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:166: FutureWarning: Setting a gradient palette using color= is deprecated and will be removed in version 0.13. Set `palette='dark:black'` for same effect.
#   warnings.warn(msg, FutureWarning)

# %%
scipy.stats.ttest_rel(perc_change_sense_saline,perc_change_sense_psilo)
# Non-significant, P=0.27
# Out:
# Ttest_relResult(statistic=array([1.21355937]), pvalue=array([0.27051582]))

# %%
z3_perc_change_saline = pd.DataFrame([0,-27.02702703,-2.985074627,-39.7260274,-32.98969072,-45.45454545,-6.097560976])
z3_perc_change_psilo = pd.DataFrame([11.11111111,-17.91044776,-11.42857143,0,-7.936507937,-41.17647059,-8.904109589])

df_perc_change_z3 = pd.DataFrame(columns=['Saline','Psilocybin'])



df_perc_change_z3['Saline'] = z3_perc_change_saline
df_perc_change_z3['Psilocybin'] = z3_perc_change_psilo

ax = sns.boxplot(data=df_perc_change_z3),
sns.stripplot(data=df_perc_change_z3,color='black')
plt.ylabel("% change in Responsive Cell Count")
plt.title("% Change in Responsive cell-count Z_3")

plt.show()
# Out:
# C:\Users\Conor\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:166: FutureWarning: Setting a gradient palette using color= is deprecated and will be removed in version 0.13. Set `palette='dark:black'` for same effect.
#   warnings.warn(msg, FutureWarning)

# %%
ID276 = [-6.097560976,-8.904109589]
ID269 = [-45.45454545,-41.17647059]
ID251 = [-32.98969072,-7.936507937]
ID239 = [-39.7260274,0]
ID237 = [-2.985074627,-11.42857143]
ID186 = [-27.02702703,-17.91044776]
ID184 = [0,11.11111111]
line1 = plt.plot(ID276,'k^-',label='276')
line2 = plt.plot(ID269,'mo-',label='269')
line3 = plt.plot(ID251,'ro-',label='251')
line4 = plt.plot(ID239,'y^-',label='239')
line5 = plt.plot(ID237,'go-',label='237')
line6 = plt.plot(ID186,'mo-',label='186')
line7 = plt.plot(ID184,'co-',label='184')


labels = ("Saline","Psilocybin")
plt.xticks(np.arange(2), labels)
plt.ylabel("% Change Active Cell Count")
plt.title("% Change in Active Cell Count for Saline and Psilocybin Conditions")

plt.show()

# %%
scipy.stats.ttest_rel(z3_perc_change_saline,z3_perc_change_psilo)
# Out:
# Ttest_relResult(statistic=array([-1.69127329]), pvalue=array([0.15157247]))

# %%
z3_perc_mean_activity_saline = pd.DataFrame([-5.072741983,-18.27057968,-22.89651799,-26.33293282,-28.88702805,-38.25565846,-23.49417366])
z3_perc_mean_activity_psilo = pd.DataFrame([-36.66287797,-9.528057419,40.53933967,6.378533853,4.930226739,-15.07740244,-9.527727359])

df_mean_activity_z3 = pd.DataFrame(columns=['Saline','Psilocybin'])



df_mean_activity_z3['Saline'] = z3_perc_mean_activity_saline
df_mean_activity_z3['Psilocybin'] = z3_perc_mean_activity_psilo

ax = sns.boxplot(data=df_mean_activity_z3),
sns.stripplot(data=df_mean_activity_z3,color='black')
plt.ylabel("% change in Responsive Cell Count")
plt.title("% Change in Responsive cell-count Z_3")

plt.show()
# Out:
# C:\Users\Conor\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:166: FutureWarning: Setting a gradient palette using color= is deprecated and will be removed in version 0.13. Set `palette='dark:black'` for same effect.
#   warnings.warn(msg, FutureWarning)

# %%
scipy.stats.ttest_rel(z3_perc_mean_activity_saline,z3_perc_mean_activity_psilo)
# Out:
# Ttest_relResult(statistic=array([-1.87549341]), pvalue=array([0.10983913]))

# %%
decon_perc_saline = pd.DataFrame([17.05069124,24.48979592,16.38418079,26.76767677,8.108108108,33.96226415,27.43362832,31.37254902])
decon_perc_psilo = pd.DataFrame([15.96091205,9.195402299,13.24786325,30.12048193,3.76344086,21.7721519,23.01587302,26.4957265])

df_decon_perc = pd.DataFrame(columns=['Saline','Psilocybin'])

df_decon_perc['Saline'] = decon_perc_saline
df_decon_perc['Psilocybin'] = decon_perc_psilo



ax = sns.boxplot(data=df_decon_perc),
sns.stripplot(data=df_decon_perc,color='black')
plt.ylabel("% of Total Matched Cells Active in Both Recordings")
plt.title("")

plt.show()
# Out:
# C:\Users\Conor\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:166: FutureWarning: Setting a gradient palette using color= is deprecated and will be removed in version 0.13. Set `palette='dark:black'` for same effect.
#   warnings.warn(msg, FutureWarning)

# %%
print(scipy.stats.ttest_ind(decon_perc_saline,decon_perc_psilo,equal_var=False))

scipy.stats.wilcoxon(decon_perc_saline,decon_perc_psilo)
# Out:
# Ttest_indResult(statistic=array([1.18861303]), pvalue=array([0.25438779]))
# WilcoxonResult(statistic=array([3.]), pvalue=array([0.0390625]))

# %%
from scipy.stats import mannwhitneyu

statistic, p_value = mannwhitneyu(decon_perc_psilo,decon_perc_saline)

print(f"Mann-Whitney U statistic: {statistic}")
print(f"P-value: {p_value}")
# Out:
# Mann-Whitney U statistic: [19.]
# P-value: [0.19487179]

# %%
ID276 = [-1.857585139,10.56338028]
ID269 = [-15.95744681,0]
ID251 = [-28.18181818,-9.638554217]
ID239 = [-16.66666667,-1.860465116]
ID237 = [12.20930233,12.8]
ID186 = [-23.23232323,-15.46961326]
ID184 = [-12.95336788,11.9047619]
line1 = plt.plot(ID276,'k^-',label='276')
line2 = plt.plot(ID269,'mo-',label='269')
line3 = plt.plot(ID251,'ro-',label='251')
line4 = plt.plot(ID239,'y^-',label='239')
line5 = plt.plot(ID237,'go-',label='237')
line6 = plt.plot(ID186,'mo-',label='186')
line7 = plt.plot(ID184,'co-',label='184')


labels = ("Saline","Psilocybin")
plt.xticks(np.arange(2), labels)
plt.ylabel("% Change Responsive Cell Count")
plt.title("% Change in Responsive Cell Count for Saline and Psilocybin Conditions")

plt.show()

# %%
decon_mean_saline = pd.DataFrame([-10.10303445,-16.51035428,-11.14837906,-23.97296713,-29.78205294,-31.39930708,-25.8027769])
decon_mean_psilo = pd.DataFrame([-10.50918791,-12.92313461,-3.359017716,-3.938794902,-0.9743182664,-29.34063882,-13.1436549])

df_decon_mean = pd.DataFrame(columns=['Saline','Psilocybin'])



df_decon_mean['Saline'] = decon_mean_saline
df_decon_mean['Psilocybin'] = decon_mean_psilo

ax = sns.boxplot(data=df_decon_mean),
sns.stripplot(data=df_decon_mean,color='black')
plt.ylabel("% change in Mean Activity Deconvolved")
plt.title("% Change in Mean Activity Deconvolved")

plt.show()
# Out:
# C:\Users\Conor\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\categorical.py:166: FutureWarning: Setting a gradient palette using color= is deprecated and will be removed in version 0.13. Set `palette='dark:black'` for same effect.
#   warnings.warn(msg, FutureWarning)

# %%
print(scipy.stats.ttest_rel(decon_mean_saline,decon_mean_psilo))
print(np.mean(decon_mean_saline))
print(sem(decon_mean_saline))

print(np.mean(decon_mean_psilo))
print(sem(decon_mean_psilo))
# Out:
# Ttest_relResult(statistic=array([-2.65406402]), pvalue=array([0.03782268]))
# 0   -21.245553
# dtype: float64
# [3.28310386]
# 0   -10.598392
# dtype: float64
# [3.62709425]
