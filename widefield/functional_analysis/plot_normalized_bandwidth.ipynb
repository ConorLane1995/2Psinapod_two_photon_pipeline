# %%
from cmath import nan
from timeit import repeat
from tkinter import Y

import numpy as np
import skimage
from skimage.io import imread
from skimage.measure import block_reduce
import os
from matplotlib import pyplot as plt
from matplotlib import cm
import pickle
import json
import scipy.io as scio
import pickle
from scipy import signal
from skimage import restoration
import scipy
import statistics
import pandas as pd
from collections import Counter
import csv

from pathlib import Path

# %%
'''
Subtract post from pre to get the difference from baseline for each.  

Then produce a mean for each one and plot that, similar to the frequencies. 

'''

# %%
FILE_PATH = "L:/widefield/bandwidth_percentages/"

# %%
csv_file_path = "L:/widefield/bandwidth_percentages/saline_day1_active.csv"

day1_saline = np.loadtxt(csv_file_path, delimiter=',')


csv_file_path = "L:/widefield/bandwidth_percentages/saline_day6_active.csv"

day6_saline = np.loadtxt(csv_file_path, delimiter=',')


csv_file_path = "L:/widefield/bandwidth_percentages/saline_day14_active.csv"

day14_saline = np.loadtxt(csv_file_path, delimiter=',')


csv_file_path = "L:/widefield/bandwidth_percentages/saline_day21_active.csv"

day21_saline = np.loadtxt(csv_file_path, delimiter=',')

# %%
diff_day6 = np.mean((day6_saline - day1_saline),axis=0)
diff_day14 = np.mean((day14_saline - day1_saline),axis=0)
diff_day21 = np.mean((day21_saline - day1_saline),axis=0)

# %%
print(diff_day6.shape)
# Out:
# (12,)

# %%
plt.plot(diff_day6)
plt.plot(diff_day14)
plt.plot(diff_day21)

# %%
csv_file_path = "L:/widefield/bandwidth_percentages/psilocybin_day1_active.csv"

day1_psilocybin = np.loadtxt(csv_file_path, delimiter=',')


csv_file_path = "L:/widefield/bandwidth_percentages/psilocybin_day6_active.csv"

day6_psilocybin = np.loadtxt(csv_file_path, delimiter=',')


csv_file_path = "L:/widefield/bandwidth_percentages/psilocybin_day14_active.csv"

day14_psilocybin = np.loadtxt(csv_file_path, delimiter=',')


csv_file_path = "L:/widefield/bandwidth_percentages/psilocybin_day21_active.csv"

day21_psilocybin = np.loadtxt(csv_file_path, delimiter=',')

# %%
diff_day6_psilo = np.mean((day6_psilocybin - day1_psilocybin),axis=0)
diff_day14_psilo = np.mean((day14_psilocybin - day1_psilocybin),axis=0)
diff_day21_psilo = np.mean((day21_psilocybin - day1_psilocybin),axis=0)

# %%
plt.plot(diff_day6_psilo,label="Day 6")
plt.plot(diff_day14_psilo)
plt.plot(diff_day21_psilo)

plt.legend()

# %%
csv_file_path = "L:/widefield/bandwidth_percentages/saline_day1_all.csv"

day1_saline_all = np.loadtxt(csv_file_path, delimiter=',')


csv_file_path = "L:/widefield/bandwidth_percentages/saline_day6_all.csv"

day6_saline_all = np.loadtxt(csv_file_path, delimiter=',')


csv_file_path = "L:/widefield/bandwidth_percentages/saline_day14_all.csv"

day14_saline_all = np.loadtxt(csv_file_path, delimiter=',')


csv_file_path = "L:/widefield/bandwidth_percentages/saline_day21_all.csv"

day21_saline_all = np.loadtxt(csv_file_path, delimiter=',')

# %%
mean_day1_saline_all = np.mean((day1_saline_all),axis=0)
mean_day6_saline_all = np.mean((day6_saline_all),axis=0)
mean_day14_saline_all = np.mean((day14_saline_all),axis=0)
mean_day21_saline_all = np.mean((day21_saline_all),axis=0)

# %%
diff_day6_all = np.mean((day6_saline_all - day1_saline_all),axis=0)
diff_day14_all = np.mean((day14_saline_all - day1_saline_all),axis=0)
diff_day21_all = np.mean((day21_saline_all - day1_saline_all),axis=0)

# %%
plt.plot(mean_day1_saline_all,label="Day 1")
plt.plot(mean_day6_saline_all,label="Day 6")
plt.plot(mean_day14_saline_all,label="Day 14")
plt.plot(mean_day21_saline_all,label="Day 21")

plt.legend()

plt.xlabel("Bandwidth (Octaves)")
# Out:
# Text(0.5, 0, 'Bandwidth (Octaves)')

# %%
plt.plot(diff_day6_all,label="Day 6")
plt.plot(diff_day14_all,label="Day 14")
plt.plot(diff_day21_all,label="Day 21")

plt.legend()

plt.xlabel("Bandwidth (Octaves)")
# Out:
# Text(0.5, 0, 'Bandwidth (Octaves)')

# %%
csv_file_path = "L:/widefield/bandwidth_percentages/psilocybin_day1_all.csv"

day1_psilocybin_all = np.loadtxt(csv_file_path, delimiter=',')


csv_file_path = "L:/widefield/bandwidth_percentages/psilocybin_day6_all.csv"

day6_psilocybin_all = np.loadtxt(csv_file_path, delimiter=',')


csv_file_path = "L:/widefield/bandwidth_percentages/psilocybin_day14_all.csv"

day14_psilocybin_all = np.loadtxt(csv_file_path, delimiter=',')


csv_file_path = "L:/widefield/bandwidth_percentages/psilocybin_day21_all.csv"

day21_psilocybin_all = np.loadtxt(csv_file_path, delimiter=',')

# %%
diff_day6_psilo_all = np.mean((day6_psilocybin_all - day1_psilocybin_all),axis=0)
diff_day14_psilo_all = np.mean((day14_psilocybin_all - day1_psilocybin_all),axis=0)
diff_day21_psilo_all = np.mean((day21_psilocybin_all - day1_psilocybin_all),axis=0)

# %%
mean_day1_psilo_all = np.mean((day1_psilocybin_all),axis=0)
mean_day6_psilo_all = np.mean((day6_psilocybin_all),axis=0)
mean_day14_psilo_all = np.mean((day14_psilocybin_all),axis=0)
mean_day21_psilo_all = np.mean((day21_psilocybin_all),axis=0)

# %%
plt.plot(diff_day6_psilo_all,label="Day 6")
plt.plot(diff_day14_psilo_all,label="Day 14")
plt.plot(diff_day21_psilo_all,label="Day 21")

plt.legend()

# %%
plt.plot(mean_day1_psilo_all,label="Day 1")
plt.plot(mean_day6_psilo_all,label="Day 6")
plt.plot(mean_day14_psilo_all,label="Day 14")
plt.plot(mean_day21_psilo_all,label="Day 21")

plt.legend()
